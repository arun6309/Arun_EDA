# %% [markdown]
# # Reading the csv file

# %% [markdown]
# import pandas as pd  # Dataframe operation
# import numpy as np # math operation
# import matplotlib.pyplot as plt #diagram/plot
# import seaborn as sns #diagrams/plots

# %%
# data set name :visa data set
# read csv file: comma separated value
# extension : .csv
# you can read this using pandas pacakage 
# path
#

# %%
import pandas as pd
path=r"C:\Users\dell\Data science\Data files\Visadataset - Visadataset.csv"

# %%
pd.read_csv(path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
#bank data set

# %%
import pandas as pd
path=r"C:\Users\dell\Data science\Data files\bank - bank.csv"
pd.read_csv(path,header=None)
# Out:
#        0              1        2          3        4        5        6     7   \
# 0     age            job  marital  education  default  balance  housing  loan
# 1      30     unemployed  married    primary       no     1787       no    no
# 2      33       services  married  secondary       no     4789      yes   yes
# 3      35     management   single   tertiary       no     1350      yes    no
# 4      30     management  married   tertiary       no     1476      yes   yes
# ...   ...            ...      ...        ...      ...      ...      ...   ...
# 4517   33       services  married  secondary       no     -333      yes    no
# 4518   57  self-employed  married   tertiary      yes    -3313      yes   yes
# 4519   57     technician  married  secondary       no      295       no    no
# 4520   28    blue-collar  married  secondary       no     1137       no    no
# 4521   44   entrepreneur   single   tertiary       no     1136      yes   yes
#
# ...

# %% [markdown]
# # create dataframe using list

# %%
name=['ramesh','suresh','sathish']
age=[30,40,50]
name,age
# Out:
# (['ramesh', 'suresh', 'sathish'], [30, 40, 50])

# %% [markdown]
# $step-1$

# %% [markdown]
# $create$ a $data$ $frame$

# %%
pd.DataFrame() # to make the data frame
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # step-2
# $provide$ $data$

# %%
pd.DataFrame(zip(name,age))
# Out:
#          0   1
# 0   ramesh  30
# 1   suresh  40
# 2  sathish  50

# %% [markdown]
# # step-3
# $provide$ $columns$

# %%
data=zip(name,age)
cols=['name','age']
pd.DataFrame(data,columns=cols)
#pd.DataFrame(data,columns=["name","age"])
# Out:
#       name  age
# 0   ramesh   30
# 1   suresh   40
# 2  sathish   50

# %% [markdown]
# # step-4
# $provide$ $index$

# %%
data=zip(name,age)
cols=['name','age']
ind=['A','B','C']
pd.DataFrame(data,columns=cols,
            index=ind)
#df=pd.DataFrame(data,columns=["name","age"],index=["a","b","c"])
# Out:
#       name  age
# A   ramesh   30
# B   suresh   40
# C  sathish   50

# %% [markdown]
# # step-5
# $add$ $new$ $column$

# %%
name=['ramesh','suresh','sathish']
age=[30,40,50]
data=zip(name,age)
cols=['name','age']
ind=['A','B','C']
df=pd.DataFrame(data,columns=cols,index=ind)
df
# Out:
#       name  age
# A   ramesh   30
# B   suresh   40
# C  sathish   50

# %% [markdown]
# - if u want to add new column
# - df['new column']
# - you need to have a list which having some elements
# - that elements need to be equal to number of rows
# - city_names=['hyd','blr','chennai']
# - df['city'=city_names]

# %%
city_names=['hyd','blr','chennai']
df['city']=city_names
df
# Out:
#       name  age     city
# A   ramesh   30      hyd
# B   suresh   40      blr
# C  sathish   50  chennai

# %% [markdown]
# # step-6
# $update$ $the$ $existing$ $columns$
# - if u want to create new coloumn or  update the old column
# - both are same way

# %%
df['name']=['arun','vamshi','chakry']
df
# Out:
#      name  age     city
# A    arun   30      hyd
# B  vamshi   40      blr
# C  chakry   50  chennai

# %% [markdown]
# ***step-7***

# %% [markdown]
# $drop$ $the$ $column$
# - in order to drop the column
# - we need to use drop method
# - it takes three parameters
# - drop the column or row
# - mention the column name
# - axis=1 reference as column
# - axis=0 refernce as row
# - if u want to create a newdataframe or
# - u want to overwrite the existing dataframe-inplace=true

# %%
df.drop('city', # column name
axis=1, # Column
inplace=True) # overwrite the same

# %%
df
# Out:
#      name  age
# A    arun   30
# B  vamshi   40
# C  chakry   50

# %%
name=['ramesh','suresh','sathish']
age=[30,40,50]
df=pd.DataFrame(zip(name,age),
columns=['name','age'],
index=['A','B','C'])
city_names=['hyd','blr','chennai']
df['city']=city_names
df.drop('city', # column name
axis=1, # Column
inplace=True) # overwrite the same
df
# Out:
#       name  age
# A   ramesh   30
# B   suresh   40
# C  sathish   50

# %% [markdown]
# # step-8
# $drop$ $rows$

# %%
df.drop('C', # column name
axis=0, # rows
inplace=True) # overwrite the same
df
# Out:
#      name  age
# A  ramesh   30
# B  suresh   40

# %% [markdown]
# # step-9
# $save$ $the$ $dataframes$

# %%
df.to_csv("output.csv")
# while saving index consider as extra column
df.to_excel("output.xlsx")

# %%
# read output csv
pd.read_csv("output.csv")
# Out:
#   Unnamed: 0    name  age
# 0          A  ramesh   30
# 1          B  suresh   40

# %% [markdown]
# # step-10
# $Remove$ $the$ $index$

# %%
# To avoid the above problem
# give index=False
df.to_csv("output.csv",index=False)

# %%
pd.read_csv("output.csv")
# Out:
#      name  age
# 0  ramesh   30
# 1  suresh   40

# %% [markdown]
# # create dataframes using dictionary

# %%
d1={"NAME":['Ramesh','Suresh','Sathish'],
"AGE":[30,35,40]}
pd.DataFrame(d1)
# No need of zip
# No need of column names
# Out:
#       NAME  AGE
# 0   Ramesh   30
# 1   Suresh   35
# 2  Sathish   40

# %% [markdown]
# **1 march 2024**

# %% [markdown]
# **import pacakages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ***Read the data****

# %%
path=r"C:\Users\dell\Data science\Data files\Visadataset - Visadataset.csv"
df=pd.read_csv(path)
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **head**

# %% [markdown]
# **top 5 rows**

# %%
#dataframe name: df
#default 5 rows
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
df.head(2)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified

# %% [markdown]
# $Tail$

# %% [markdown]
# **Last 5 rows**

# %%
df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
df.tail(2)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25478                 West         86154.77         Year                  Y
# 25479              Midwest         70876.91         Year                  Y
#
#       case_status
# 25478   Certified
# 25479   Certified

# %% [markdown]
# $shape$

# %% [markdown]
# **Number of rows and number of columns**

# %%
df.shape
# Out:
# (25480, 12)

# %%
print("the number of rows:",df.shape[0])
print("the number of columns:",df.shape[1])
# Out:
# the number of rows: 25480
# the number of columns: 12

# %% [markdown]
# $size$

# %% [markdown]
# **how many indices are there provided by size**

# %%
df.size
# Out:
# 305760

# %% [markdown]
# $columns$

# %%
df.columns #all the columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# $dtypes$

# %% [markdown]
# **data types**

# %%
df.dtypes
# object means categoricals
# other than objects are numerical
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# $task-1$

# %% [markdown]
# **extract numerical columns and categorical columns separetly by using dtypes**

# %%
#convert above into dictionary
#keys and values
#if for list 
dict(df.dtypes)
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
d1=dict(df.dtypes)
#for i in d1
#if d1[i]=='object':
#print(i)
cat=[i for i in d1 if d1[i]=='object']
num=[i for i in d1 if d1[i]!='object']

# %%
cat
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
num
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
#catergorical data available
df.select_dtypes(include='object')
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training region_of_employment unit_of_wage  \
# 0                         N                 West         Hour
# ...

# %%
# if we add .columns at end we get categorical data we get
df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
#numerical data 
df.select_dtypes(exclude='object')
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage
# 0                14513         2007         592.2029
# 1                 2412         2002       83425.6500
# 2                44444         2008      122996.8600
# 3                   98         1897       83434.0300
# 4                 1082         2005      149907.3900
# ...                ...          ...              ...
# 25475             2601         2008       77092.5700
# 25476             3274         2006      279174.7900
# 25477             1121         1910      146298.8500
# 25478             1918         1887       86154.7700
# 25479             3195         1960       70876.9100
#
# [25480 rows x 3 columns]

# %%
# if we add .columns at end we get numericall data we get
df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# $isnull$

# %% [markdown]
# **identify if data has any missing values or null value**

# %%
df.isnull()
# true means (yes) there is a null value
#false mean (no) there is no null values
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
#when u open an excel sheet the data has empty
#which mean the data is missed
#when u read that using pandas
#at that particular position it will display as Null

# %% [markdown]
# **if we want to find how many null columns**

# %%
#if we want to find how many null columns
df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# ***drop duplicate values***

# %%
df.drop_duplicates()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $info$

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
len(df)
# Out:
# 25480

# %% [markdown]
# - head
# - tail
# - shape
# - size
# - columns
# - dtypes
# - isnull
# - isnull().sum()
# - drop duplicates
# - info
# - len

# %% [markdown]
# # bound method
#    - you need to keep brackets
# # Not callable
#    - you need to remove brackets
# # Attribute error
#     - the method is not available
#     - check spelling mistakes

# %%
# we want read some sample of data
# we know head will give top 5 
# we know tail give last 5 
# if u want to specify rows and columns

# %% [markdown]
# **take-loc-iloc**

# %%
df.take([2,3,4])
# 2,3,4 are the same columns and rows
# axis=1 refernce as columns
# axis=0 refrence as rows
# by default axis=0
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 2        122996.86         Year                  Y      Denied
# 3         83434.03         Year                  Y      Denied
# 4        149907.39         Year                  Y   Certified

# %%
df.take([2,3,4],axis=1)
# Out:
#       education_of_employee has_job_experience requires_job_training
# 0               High School                  N                     N
# 1                  Master's                  Y                     N
# 2                Bachelor's                  N                     Y
# 3                Bachelor's                  N                     N
# 4                  Master's                  Y                     N
# ...                     ...                ...                   ...
# 25475            Bachelor's                  Y                     Y
# 25476           High School                  Y                     N
# 25477              Master's                  Y                     N
# 25478              Master's                  Y                     Y
# 25479            Bachelor's                  Y                     N
#
# [25480 rows x 3 columns]

# %%
df.take([100,200,300])
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
# i want 100,200,300 rows from  4,8,11 columns
df.take([100,200,300]).take([4,8,11],axis=1)
# Out:
#     requires_job_training  prevailing_wage case_status
# 100                     N         28243.79   Certified
# 200                     N         74441.11   Certified
# 300                     N        101371.21   Certified

# %% [markdown]
# - note: take does not take rows and columns at a time

# %% [markdown]
# $iloc$

# %%
# df.iloc[<rows>,<columns>]
# df.iloc[<start:end>,<start:end>]
# rows=[]
# columns=[]
# df.iloc(rows,columns)

# %%
df.iloc[5:10]  # all the columns
# Out:
#    case_id      continent education_of_employee has_job_experience  \
# 5   EZYV06           Asia              Master's                  Y
# 6   EZYV07           Asia            Bachelor's                  N
# 7   EZYV08  North America            Bachelor's                  Y
# 8   EZYV09           Asia            Bachelor's                  N
# 9   EZYV10         Europe             Doctorate                  Y
# 10  EZYV11           Asia              Master's                  N
# 11  EZYV12           Asia           High School                  Y
# 12  EZYV13           Asia            Bachelor's                  Y
# 13  EZYV14           Asia            Bachelor's                  Y
# 14  EZYV15           Asia              Master's                  Y
# 15  EZYV16           Asia           High School                  Y
# 16  EZYV17         Europe              Master's                  Y
# 17  EZYV18           Asia              Master's                  Y
# ...

# %%
df.iloc[5:10,2:5]# specific rows and columns
# Out:
#   education_of_employee has_job_experience requires_job_training
# 5              Master's                  Y                     N
# 6            Bachelor's                  N                     N
# 7            Bachelor's                  Y                     N
# 8            Bachelor's                  N                     N
# 9             Doctorate                  Y                     N

# %%
df.iloc[:,2:5] #all the rows
# Out:
#       education_of_employee has_job_experience requires_job_training
# 0               High School                  N                     N
# 1                  Master's                  Y                     N
# 2                Bachelor's                  N                     Y
# 3                Bachelor's                  N                     N
# 4                  Master's                  Y                     N
# ...                     ...                ...                   ...
# 25475            Bachelor's                  Y                     Y
# 25476           High School                  Y                     N
# 25477              Master's                  Y                     N
# 25478              Master's                  Y                     Y
# 25479            Bachelor's                  Y                     N
#
# [25480 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
# only previling data
df.iloc[[100,200,300],[8]]
# no bracket :series
# bracket is there: dataframe
# Out:
#      prevailing_wage
# 100         28243.79
# 200         74441.11
# 300        101371.21

# %%
df.iloc[[100,200,300],[10]]
# Out:
#     full_time_position
# 100                  Y
# 200                  Y
# 300                  Y

# %% [markdown]
# $loc$

# %%
df.loc[[100,200,300],['full_time_position']]
# loc will consider column name
# Out:
#     full_time_position
# 100                  Y
# 200                  Y
# 300                  Y
